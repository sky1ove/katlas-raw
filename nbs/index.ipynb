# %%
#| hide
from katlas_raw.core import *

# %% [markdown]
# # katlas-raw
#
# > Raw code to reproduce data and figures in the paper of KATLAS

# %% [markdown]
# ## Install katlas in Development mode

# %% [markdown]
# ```sh
# $ pip install "python-katlas[dev]"
# ```

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/sky1ove/katlas-raw
# [docs]: https://sky1ove.github.io/katlas-raw/
# [pypi]: https://pypi.org/project/katlas-raw/
# [conda]: https://anaconda.org/sky1ove/katlas-raw

# %% [markdown]
# ## Directory

# %% [markdown]
# Under nbs folder, check each .ipyn notebook to generate data and figures

# %% [markdown]
# Under nbs/kinase_domain, check more training details of kinase domain
